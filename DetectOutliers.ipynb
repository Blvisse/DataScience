# %% [markdown]
# <a href="https://colab.research.google.com/github/Blvisse/DataScience/blob/master/DetectOutliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-8da37ee2-32b0-4411-bc87-0315f44458f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8da37ee2-32b0-4411-bc87-0315f44458f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winequality-red.csv to winequality-red.csv
# ...

# %%
data=pd.read_csv('winequality-red.csv')

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %% [markdown]
# # Boxplots

# %%
plt.figure(figsize=(25,18))
sns.boxplot(data=data)

# %% [markdown]
# # DBScan Clustering

# %%
outliersDetection=DBSCAN(min_samples=3,eps=3)
clusters=outliersDetection.fit_predict(data)
list(clusters).count(-1)
# Out:
# 245
